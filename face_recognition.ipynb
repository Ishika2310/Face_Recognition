# %%
import cv2
import numpy as np
import threading


# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path = './faces/user/' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face not found")
        pass

    if cv2.waitKey(1) == 13 or count == 100: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")
# Out:
# <>:17: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:17: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-6-718938d24814>:17: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# Face not found
# Collecting Samples Complete

# %%
cap.release()

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join

# Get the training data we previously made
data_path = './faces/user/'
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

# Create arrays for training data and labels
Training_Data, Labels = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles):
    image_path = data_path + onlyfiles[i]
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)

# Create a numpy array for both training data and labels
Labels = np.asarray(Labels, dtype=np.int32)

# Initialize facial recognizer
# model = cv2.face.createLBPHFaceRecognizer()
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()
# pip install opencv-contrib-python
# model = cv2.createLBPHFaceRecognizer()
ishika_model  = cv2.face_LBPHFaceRecognizer.create()
# Let's train our model 
ishika_model.train(np.asarray(Training_Data), np.asarray(Labels))
print("Model trained sucessefully")
# Out:
# Model trained sucessefully

# %%
#mail function
def mail():
    os.system("python mail.py")
#Whatsapp function
def whatsapp():
    os.system("python whatsapp.py")

# %%
import cv2
import numpy as np
import os


face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []
    
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()
    
    image, face = face_detector(frame)
    
    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = ishika_model.predict(face)
        # harry_model.predict(face)
        
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/650) )
            display_string = str(confidence) + '% Confident it is User'
            
        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        if confidence > 90:
            cv2.putText(image, "Hey Ishika", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
           
             #For sending mail
            mail=threading.Thread(target=mail)
            mail.start()
            #For Whatsapp
            whatsapp=threading.Thread(target=whatsapp)
            whatsapp.start()
            
        
        
        else:
            
            cv2.putText(image, "I dont know, how r u", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "looking for face", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass
        
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-12-509cc63239a3>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# Exception in thread Exception in thread Thread-12:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-13:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-14:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-16:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-17:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-18:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-19:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-20:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-21:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-22:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-23:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-24:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-25:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-27:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-28Exception in thread :
# Thread-29:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-30:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-31:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-32:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-33:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-34:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-35:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-36:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-37:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-38:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-39:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-40:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-41:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-42:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-43:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-44:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-45:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-46:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-47:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-48:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-49:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-50:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-51:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-52:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-53:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-54:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-55:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-56:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-57:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-58:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-59:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-60:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-61:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-62:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-63:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-64:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-65:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-66:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-67:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-68:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-69:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-70:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-71:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-72:
# Exception in thread Traceback (most recent call last):
# Thread-73:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-74:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-75:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-76:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-77:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-78:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-79:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-80:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-81:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: self._target(*self._args, **self._kwargs)
# 'Thread' object is not callable
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-82:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-83:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-84:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-85:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-86:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-87:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-88:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-89:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-90:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-91:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-92:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-93:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-94:
# Traceback (most recent call last):
# Exception in thread   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-95:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-96Thread-97:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError:     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# 'Thread' object is not callable
# Exception in thread Thread-98:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-99:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-100:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-101:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-102:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-103:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-104:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-105:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-106:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-107:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-108:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-109:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-110:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-111:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-112Thread-113:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-114:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-115:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-116:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-117:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-118:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-119:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-120:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-121:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-122:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-123:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-124:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-125:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-126:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-127:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-128:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-129:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-130:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-131:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-132:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-133:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-134:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-135:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-136:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-137:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-138:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-139:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-140:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-141:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-142:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-143:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-144:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-145:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-146:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-147:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-148:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-149:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-150:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-151:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-152:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-153:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-154:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-155:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-156:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-157:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-158:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-159:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# ...
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-162:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-163:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-164:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-165:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-167:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-166:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-168:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-169:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-170:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-171:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-172:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-173:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-174:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-175:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-176:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-177:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-178:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-179:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-181:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-180:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-182:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-183:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-184:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-185:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-186:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-187:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-188:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-189:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-190:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-191:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-192:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-193:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-194:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-195:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-196:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-197:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-198:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-199:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-201:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-200:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-202:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-203:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callableself._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#
# Exception in thread Thread-204:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-205:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-206:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-207:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-208:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-209:
# Traceback (most recent call last):
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Ishika\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# TypeError: 'Thread' object is not callable
